# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
print(tf.config.list_physical_devices('GPU'))
import cv2
import imghdr
data_dir = 'signatures' 
image_exts = ['jpeg','jpg', 'bmp', 'png']
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
data = tf.keras.utils.image_dataset_from_directory('signatures')
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile('Nadam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='nadam'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=30, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 58/58 [==============================] - 14s 93ms/step - loss: 0.7337 - accuracy: 0.5571 - val_loss: 0.6609 - val_accuracy: 0.6914
# Epoch 2/30
# 58/58 [==============================] - 5s 80ms/step - loss: 0.5911 - accuracy: 0.6897 - val_loss: 0.5269 - val_accuracy: 0.7539
# Epoch 3/30
# 58/58 [==============================] - 5s 79ms/step - loss: 0.4844 - accuracy: 0.7710 - val_loss: 0.4721 - val_accuracy: 0.7988
# Epoch 4/30
# 58/58 [==============================] - 5s 79ms/step - loss: 0.3878 - accuracy: 0.8244 - val_loss: 0.4283 - val_accuracy: 0.8125
# Epoch 5/30
# 58/58 [==============================] - 5s 79ms/step - loss: 0.3135 - accuracy: 0.8669 - val_loss: 0.8756 - val_accuracy: 0.7285
# Epoch 6/30
# 58/58 [==============================] - 5s 80ms/step - loss: 0.2033 - accuracy: 0.9154 - val_loss: 0.3952 - val_accuracy: 0.8535
# Epoch 7/30
# 58/58 [==============================] - 5s 80ms/step - loss: 0.1445 - accuracy: 0.9520 - val_loss: 0.3879 - val_accuracy: 0.8535
# Epoch 8/30
# 58/58 [==============================] - 5s 82ms/step - loss: 0.0581 - accuracy: 0.9828 - val_loss: 0.3811 - val_accuracy: 0.8848
# Epoch 9/30
# 58/58 [==============================] - 5s 80ms/step - loss: 0.0838 - accuracy: 0.9811 - val_loss: 1.0921 - val_accuracy: 0.7129
# Epoch 10/30
# 58/58 [==============================] - 5s 81ms/step - loss: 0.0210 - accuracy: 0.9952 - val_loss: 0.4327 - val_accuracy: 0.8828
# Epoch 11/30
# 58/58 [==============================] - 5s 85ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.8926
# Epoch 12/30
# 58/58 [==============================] - 5s 88ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 1.4540 - val_accuracy: 0.7754
# Epoch 13/30
# 58/58 [==============================] - 5s 84ms/step - loss: 0.0341 - accuracy: 0.9903 - val_loss: 0.4503 - val_accuracy: 0.8887
# Epoch 14/30
# 58/58 [==============================] - 5s 81ms/step - loss: 0.0200 - accuracy: 0.9935 - val_loss: 0.4771 - val_accuracy: 0.8672
# Epoch 15/30
# 58/58 [==============================] - 5s 81ms/step - loss: 0.0123 - accuracy: 0.9973 - val_loss: 1.5117 - val_accuracy: 0.7637
# Epoch 16/30
# 58/58 [==============================] - 5s 80ms/step - loss: 0.0223 - accuracy: 0.9935 - val_loss: 0.5142 - val_accuracy: 0.8770
# Epoch 17/30
# 58/58 [==============================] - 5s 83ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.9121
# Epoch 18/30
# 58/58 [==============================] - 5s 82ms/step - loss: 4.9169e-04 - accuracy: 1.0000 - val_loss: 0.6099 - val_accuracy: 0.9102
# Epoch 19/30
# 58/58 [==============================] - 5s 83ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.6198 - val_accuracy: 0.8477
# Epoch 20/30
# 58/58 [==============================] - 5s 81ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 0.5540 - val_accuracy: 0.9004
# Epoch 21/30
# 58/58 [==============================] - 5s 82ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5920 - val_accuracy: 0.9082
# Epoch 22/30
# 58/58 [==============================] - 5s 82ms/step - loss: 2.9345e-04 - accuracy: 1.0000 - val_loss: 0.6184 - val_accuracy: 0.9062
# Epoch 23/30
# 58/58 [==============================] - 5s 83ms/step - loss: 1.8634e-04 - accuracy: 1.0000 - val_loss: 0.5974 - val_accuracy: 0.9082
# Epoch 24/30
# 58/58 [==============================] - 5s 84ms/step - loss: 2.0952e-04 - accuracy: 1.0000 - val_loss: 0.5783 - val_accuracy: 0.9082
# Epoch 25/30
# 58/58 [==============================] - 5s 83ms/step - loss: 1.2420e-04 - accuracy: 1.0000 - val_loss: 0.6378 - val_accuracy: 0.9141
# Epoch 26/30
# 58/58 [==============================] - 5s 83ms/step - loss: 1.6569e-04 - accuracy: 1.0000 - val_loss: 0.6794 - val_accuracy: 0.9023
# Epoch 27/30
# 58/58 [==============================] - 5s 83ms/step - loss: 7.8013e-05 - accuracy: 1.0000 - val_loss: 0.5709 - val_accuracy: 0.9082
# Epoch 28/30
# 58/58 [==============================] - 5s 83ms/step - loss: 6.9496e-05 - accuracy: 1.0000 - val_loss: 0.5473 - val_accuracy: 0.9180
# Epoch 29/30
# 58/58 [==============================] - 5s 85ms/step - loss: 5.9615e-05 - accuracy: 1.0000 - val_loss: 0.6412 - val_accuracy: 0.9043
# Epoch 30/30
# 58/58 [==============================] - 5s 84ms/step - loss: 0.0098 - accuracy: 0.9995 - val_loss: 0.7127 - val_accuracy: 0.8926

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.8476821, shape=(), dtype=float32) tf.Tensor(0.93430656, shape=(), dtype=float32) tf.Tensor(0.875, shape=(), dtype=float32)

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('signatures/full_org/original_13_19.png')
plt.imshow(img)
plt.show()
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
yhat
# Out:
# array([[1.]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is original')
else:
    print(f'Predicted class is forged')
# Out:
# Predicted class is original

# %%
from tensorflow.keras.models import load_model
model.save(os.path.join('models','nadam.h5'))

# %%
new_model = load_model('models/imageclassifier.h5')

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 46ms/step
# array([[0.69642204]], dtype=float32)
